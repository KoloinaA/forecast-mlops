# %%
import pandas as pd

df = pd.read_csv("../data/raw/train.csv")

df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
df.shape
# Out:
# (3000888, 6)

# %%
df.columns
# Out:
# Index(['id', 'date', 'store_nbr', 'family', 'sales', 'onpromotion'], dtype='str')

# %%
df.dtypes
# Out:
# id               int64
# date               str
# store_nbr        int64
# family             str
# sales          float64
# onpromotion      int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3000883            0
# 3000884            1
# 3000885          148
# 3000886            8
# 3000887            0
#
# [3000888 rows x 6 columns]>

# %%
df.isna().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %%
(df.isna().sum()/len(df))*100
# Out:
# id             0.0
# date           0.0
# store_nbr      0.0
# family         0.0
# sales          0.0
# onpromotion    0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date, store_nbr, family, sales, onpromotion]
# Index: []

# %%
import matplotlib.pyplot as plt

df["sales"].hist(bins=40)

plt.show()

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["date"].min()
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
df["date"].max()
# Out:
# Timestamp('2017-08-15 00:00:00')

# %%
daily_sales = df.groupby("date")["sales"].sum()

daily_sales.plot(figsize=(15,5))
# Out:
# <Axes: xlabel='date'>

# %%
df["family"].value_counts()
# Out:
# family
# AUTOMOTIVE                    90936
# BABY CARE                     90936
# BEAUTY                        90936
# BEVERAGES                     90936
# BOOKS                         90936
# BREAD/BAKERY                  90936
# CELEBRATION                   90936
# CLEANING                      90936
# DAIRY                         90936
# DELI                          90936
# EGGS                          90936
# FROZEN FOODS                  90936
# GROCERY I                     90936
# GROCERY II                    90936
# HARDWARE                      90936
# HOME AND KITCHEN I            90936
# HOME AND KITCHEN II           90936
# HOME APPLIANCES               90936
# HOME CARE                     90936
# LADIESWEAR                    90936
# LAWN AND GARDEN               90936
# LINGERIE                      90936
# LIQUOR,WINE,BEER              90936
# MAGAZINES                     90936
# MEATS                         90936
# PERSONAL CARE                 90936
# PET SUPPLIES                  90936
# PLAYERS AND ELECTRONICS       90936
# POULTRY                       90936
# PREPARED FOODS                90936
# PRODUCE                       90936
# SCHOOL AND OFFICE SUPPLIES    90936
# SEAFOOD                       90936
# Name: count, dtype: int64

# %%
df["store_nbr"].nunique()
# Out:
# 54

# %%
df.corr(numeric_only=True)
# Out:
#                    id  store_nbr     sales  onpromotion
# id           1.000000   0.000301  0.085784     0.206260
# store_nbr    0.000301   1.000000  0.041196     0.007286
# sales        0.085784   0.041196  1.000000     0.427923
# onpromotion  0.206260   0.007286  0.427923     1.000000

# %%
df.boxplot(column="sales")
# Out:
# <Axes: >

# %%
import functions as fun

import pandas as pd
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns', 100)

fun.unistats(df)
# Out:
#                Count  Missing   Unique           Dtype  Numeric  \
# onpromotion  3000888        0      362           int64     True
# sales        3000888        0   379610         float64     True
# store_nbr    3000888        0       54           int64     True
# id           3000888        0  3000888           int64     True
# date         3000888        0     1684  datetime64[us]    False
# family       3000888        0       33             str    False
#
#                             Mode        Mean  Min        25%     Median  \
# onpromotion                    0     2.60277    0        0.0        0.0
# sales                        0.0  357.775749  0.0        0.0       11.0
# store_nbr                      1        27.5    1       14.0       27.5
# id                             0   1500443.5    0  750221.75  1500443.5
# date         2013-01-01 00:00:00           -    -          -          -
# family                AUTOMOTIVE           -    -          -          -
#
#                     75%       Max            Std       Skew    Kurtosis
# onpromotion         0.0       741      12.218882  11.166562  240.871122
# sales         195.84725  124717.0    1101.997721   7.358758  154.562092
# store_nbr          41.0        54      15.585787        0.0   -1.200823
# id           2250665.25   3000887  866281.891642       -0.0        -1.2
# date                  -         -              -          -           -
# family                -         -              -          -           -
